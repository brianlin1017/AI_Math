# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# $f(x) = (x+1)(x-2)(x+3)(4x-5)$
#
#
# $\frac{\mathrm{d} f(x)}{\mathrm{d} x} = 16x^3+9x^2-60x+1$

# %%
x = np.linspace(-3, 3, 100)
y = (x + 1) * (x - 2) * (x + 3) * (4 * x - 5)

# %%
plt.plot(x,y)

# %%
def Loss(x):
    return (x + 1) * (x - 2) * (x + 3) * (4 * x - 5)

def gradient_descent(x):
    return 16 * np.power(x,3) - 9*np.power(x,2) - 60 * x + 1

# %%
def find_minimum(x):
    
    X = np.linspace(-3, 3, 100)
    Y = Loss(X)
    plt.plot(X, Y)
    
    η = 0.01
    
    for i in range(50):
        x = x - η * gradient_descent(x)
        y = Loss(x) 
        plt.scatter(x, y, color = 'r')

# %%
find_minimum(0)

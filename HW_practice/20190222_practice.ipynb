# %%
1+1
# Out:
# 2

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
numpy.sin(1)
# Out:
# 0.8414709848078965

# %%
numpy.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### 附註
#
# matplotlib 名稱來源
# Matlab--Plot--Lib

# %%
plt.plot([1, 37, 25, 68])

# %%
plt.plot([1, 2, 3, 4],[3, 7.2, -5.7, 68])

# %%
X = [1.2, 1.7, 2, 3]
Y = [9, 0.5, 2.4, -7]

# %%
plt.plot(X,Y)

# %%
plt.scatter(X,Y)

# %%
np.random.rand(7)
# Out:
# array([0.92328277, 0.7052679 , 0.04926674, 0.13078317, 0.43951078,
#        0.75004077, 0.29150512])

# %% [markdown]
# 0-1 隨機數

# %%
np.random.randn(7)
# Out:
# array([ 1.9685247 ,  0.07515824,  1.6726689 , -0.41349168,  1.39890059,
#        -1.43010306, -0.20701393])

# %% [markdown]
# 平均0
# 標準差1

# %%
plt.plot(np.random.rand(100))

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x, y)

# %%
plt.xkcd()

# %% [markdown]
# 打了就很難救回來

# %%
plt.plot(x, y)

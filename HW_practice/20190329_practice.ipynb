# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")

# %%
df1.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
colname = ['1. sepal length in cm ', '2. sepal width in cm' , '3. petal length in cm' , '4. petal width in cm ', '5. class:' ]

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",
                names = colname,
                header = None)

# %%
df.head()
# Out:
#    1. sepal length in cm   2. sepal width in cm  3. petal length in cm  \
# 0                     5.1                   3.5                    1.4
# 1                     4.9                   3.0                    1.4
# 2                     4.7                   3.2                    1.3
# 3                     4.6                   3.1                    1.5
# 4                     5.0                   3.6                    1.4
#
#    4. petal width in cm     5. class:
# 0                    0.2  Iris-setosa
# 1                    0.2  Iris-setosa
# 2                    0.2  Iris-setosa
# 3                    0.2  Iris-setosa
# 4                    0.2  Iris-setosa

# %%
df.sample(5)
# Out:
#      1. sepal length in cm   2. sepal width in cm  3. petal length in cm  \
# 113                     5.7                   2.5                    5.0
# 146                     6.3                   2.5                    5.0
# 76                      6.8                   2.8                    4.8
# 37                      4.9                   3.1                    1.5
# 108                     6.7                   2.5                    5.8
#
#      4. petal width in cm         5. class:
# 113                    2.0   Iris-virginica
# 146                    1.9   Iris-virginica
# 76                     1.4  Iris-versicolor
# 37                     0.1      Iris-setosa
# 108                    1.8   Iris-virginica

# %%
df.describe()
# Out:
#        1. sepal length in cm   2. sepal width in cm  3. petal length in cm  \
# count              150.000000            150.000000             150.000000
# mean                 5.843333              3.054000               3.758667
# std                  0.828066              0.433594               1.764420
# min                  4.300000              2.000000               1.000000
# 25%                  5.100000              2.800000               1.600000
# 50%                  5.800000              3.000000               4.350000
# 75%                  6.400000              3.300000               5.100000
# max                  7.900000              4.400000               6.900000
#
#        4. petal width in cm
# count             150.000000
# mean                1.198667
# std                 0.763161
# min                 0.100000
# 25%                 0.300000
# 50%                 1.300000
# 75%                 1.800000
# max                 2.500000

# %%
df.dtypes
# Out:
# 1. sepal length in cm     float64
# 2. sepal width in cm      float64
# 3. petal length in cm     float64
# 4. petal width in cm      float64
# 5. class:                  object
# dtype: object

# %%
df["1. sepal length in cm "]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
# 5      5.4
# 6      4.6
# 7      5.0
# 8      4.4
# 9      4.9
# 10     5.4
# 11     4.8
# 12     4.8
# 13     4.3
# 14     5.8
# 15     5.7
# 16     5.4
# 17     5.1
# 18     5.7
# 19     5.1
# 20     5.4
# 21     5.1
# 22     4.6
# 23     5.1
# 24     4.8
# 25     5.0
# 26     5.0
# 27     5.2
# 28     5.2
# 29     4.7
#       ...
# 120    6.9
# 121    5.6
# 122    7.7
# 123    6.3
# 124    6.7
# 125    7.2
# 126    6.2
# 127    6.1
# 128    6.4
# 129    7.2
# 130    7.4
# 131    7.9
# 132    6.4
# 133    6.3
# 134    6.1
# 135    7.7
# 136    6.3
# 137    6.4
# 138    6.0
# 139    6.9
# 140    6.7
# 141    6.9
# 142    5.8
# 143    6.8
# 144    6.7
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: 1. sepal length in cm , dtype: float64

# %% [markdown]
# 想咬data frame

# %%
df[["1. sepal length in cm "]]
# Out:
#      1. sepal length in cm
# 0                       5.1
# 1                       4.9
# 2                       4.7
# 3                       4.6
# 4                       5.0
# 5                       5.4
# 6                       4.6
# 7                       5.0
# 8                       4.4
# 9                       4.9
# 10                      5.4
# 11                      4.8
# 12                      4.8
# 13                      4.3
# 14                      5.8
# 15                      5.7
# 16                      5.4
# 17                      5.1
# 18                      5.7
# 19                      5.1
# 20                      5.4
# 21                      5.1
# 22                      4.6
# 23                      5.1
# 24                      4.8
# 25                      5.0
# 26                      5.0
# 27                      5.2
# 28                      5.2
# 29                      4.7
# ..                      ...
# 120                     6.9
# ...

# %%
df["1. sepal length in cm "].to_frame("nameyouwant")
# Out:
#      nameyouwant
# 0            5.1
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0
# 5            5.4
# 6            4.6
# 7            5.0
# 8            4.4
# 9            4.9
# 10           5.4
# 11           4.8
# 12           4.8
# 13           4.3
# 14           5.8
# 15           5.7
# 16           5.4
# 17           5.1
# 18           5.7
# 19           5.1
# 20           5.4
# 21           5.1
# 22           4.6
# 23           5.1
# 24           4.8
# 25           5.0
# 26           5.0
# 27           5.2
# 28           5.2
# 29           4.7
# ..           ...
# 120          6.9
# 121          5.6
# 122          7.7
# 123          6.3
# 124          6.7
# 125          7.2
# 126          6.2
# 127          6.1
# 128          6.4
# 129          7.2
# 130          7.4
# 131          7.9
# 132          6.4
# 133          6.3
# 134          6.1
# 135          7.7
# 136          6.3
# 137          6.4
# 138          6.0
# 139          6.9
# ...

# %% [markdown]
# ### 想指定 只要幾行 幾列 的資料

# %%
df[0:2][["1. sepal length in cm ",'2. sepal width in cm']]
# Out:
#    1. sepal length in cm   2. sepal width in cm
# 0                     5.1                   3.5
# 1                     4.9                   3.0

# %%
df.loc[[0, 5], ["1. sepal length in cm ",'2. sepal width in cm']]
# Out:
#    1. sepal length in cm   2. sepal width in cm
# 0                     5.1                   3.5
# 5                     5.4                   3.9

# %%
df.iloc[2:6, 2:4]
# Out:
#    3. petal length in cm  4. petal width in cm
# 2                    1.3                    0.2
# 3                    1.5                    0.2
# 4                    1.4                    0.2
# 5                    1.7                    0.4

# %% [markdown]
# ### nan

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.isna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-655d9ae5017a> in <module>
# ----> 1 ufo.isna()
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
ufo.isnull()
# Out:
#         City Colors Reported Shape Reported  State   Time
# 0      False            True          False  False  False
# 1      False            True          False  False  False
# 2      False            True          False  False  False
# 3      False            True          False  False  False
# 4      False            True          False  False  False
# 5      False            True          False  False  False
# 6      False            True          False  False  False
# 7      False            True          False  False  False
# 8      False            True          False  False  False
# 9      False            True          False  False  False
# 10     False            True          False  False  False
# 11     False            True          False  False  False
# 12     False           False          False  False  False
# 13     False            True          False  False  False
# 14     False            True          False  False  False
# ...

# %%
ufo.isnull().any()
# Out:
# City                True
# Colors Reported     True
# Shape Reported      True
# State              False
# Time               False
# dtype: bool

# %%
ufo.isnull().any().any()
# Out:
# True

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.isnull().sum().sum()
# Out:
# 18028

# %%
ufo.dropna()
# Out:
#                     City Colors Reported Shape Reported State  \
# 12                Belton             RED         SPHERE    SC
# 19            Bering Sea             RED          OTHER    AK
# 36            Portsmouth             RED      FORMATION    VA
# 44             Blairsden           GREEN         SPHERE    CA
# 82              San Jose            BLUE        CHEVRON    CA
# 84               Modesto            BLUE           DISK    CA
# 91                Scipio             RED         SPHERE    IN
# 111         Tarrant City          ORANGE         CIRCLE    AL
# 129                 Napa           GREEN           DISK    CA
# 138        Coeur d'Alene          ORANGE          CIGAR    ID
# 152               Irving            BLUE           DISK    KS
# 157           Greenville           GREEN           DISK    MS
# 163          Green River           GREEN         SPHERE    WY
# 164                Provo            BLUE           DISK    UT
# ...

# %%
ufo.dropna(axis = 1)
# Out:
#       State              Time
# 0        NY    6/1/1930 22:00
# 1        NJ   6/30/1930 20:00
# 2        CO   2/15/1931 14:00
# 3        KS    6/1/1931 13:00
# 4        NY   4/18/1933 19:00
# 5        ND   9/15/1934 15:30
# 6        CA    6/15/1935 0:00
# 7        MI    7/15/1936 0:00
# 8        AK  10/15/1936 17:00
# 9        OR    6/15/1937 0:00
# 10       CA   8/15/1937 21:00
# 11       AL    6/1/1939 20:00
# 12       SC   6/30/1939 20:00
# 13       IA     7/7/1939 2:00
# 14       MI    6/1/1941 13:00
# 15       CA    7/2/1941 11:30
# 16       CA    2/25/1942 0:00
# 17       GA    6/1/1942 22:30
# 18       TN    7/15/1942 1:00
# 19       AK   4/30/1943 23:00
# 20       NE    6/1/1943 15:00
# 21       LA    8/15/1943 0:00
# 22       LA    8/15/1943 0:00
# 23       KY  10/15/1943 11:00
# 24       WV    1/1/1944 10:00
# 25       CA    1/1/1944 12:00
# 26       WV    1/1/1944 12:00
# 27       NM    4/2/1944 11:00
# 28       NM    6/1/1944 12:00
# 29       UT   6/30/1944 10:00
# ...

# %%
ufo.fillna(0)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca               0       TRIANGLE    NY
# 1               Willingboro               0          OTHER    NJ
# 2                   Holyoke               0           OVAL    CO
# 3                   Abilene               0           DISK    KS
# 4      New York Worlds Fair               0          LIGHT    NY
# 5               Valley City               0           DISK    ND
# 6               Crater Lake               0         CIRCLE    CA
# 7                      Alma               0           DISK    MI
# 8                   Eklutna               0          CIGAR    AK
# 9                   Hubbard               0       CYLINDER    OR
# 10                  Fontana               0          LIGHT    CA
# 11                 Waterloo               0       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(inplace = True)

# %%
ufo.isnull().any()
# Out:
# City               False
# Colors Reported    False
# Shape Reported     False
# State              False
# Time               False
# dtype: bool

# %%
ufo = ufo.dropna()

# %% [markdown]
# ### groupby

# %%
ufo = pd.read_csv("http://bit.ly/uforeports")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_state = ufo.groupby("State")

# %%
ufo_state

# %%
ufo_state.count()
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
ufo_state.sum()
# Out:
#                                                     Time
# State
# AK     10/15/1936 17:004/30/1943 23:006/10/1949 21:00...
# AL     6/1/1939 20:007/1/1949 16:008/15/1949 22:006/3...
# AR     4/15/1950 8:008/15/1952 17:307/1/1955 22:009/2...
# AZ     9/30/1946 20:306/15/1952 0:005/20/1953 8:009/1...
# CA     6/15/1935 0:008/15/1937 21:007/2/1941 11:302/2...
# CO     2/15/1931 14:006/30/1950 17:306/30/1950 17:306...
# CT     6/4/1949 10:002/3/1951 22:001/15/1954 20:007/1...
# Ca                                       4/15/1992 22:00
# DE     6/15/1954 11:459/30/1964 0:007/1/1966 0:308/9/...
# FL     7/15/1944 13:006/1/1945 13:304/15/1947 14:006/...
# Fl     4/28/1996 0:105/17/1996 1:305/22/1996 20:305/2...
# GA     6/1/1942 22:307/1/1951 14:006/6/1954 10:006/30...
# HI     10/10/1960 20:005/15/1966 17:006/1/1967 0:006/...
# IA     7/7/1939 2:004/10/1953 13:001/1/1954 22:006/30...
# ID     7/15/1947 15:007/2/1950 13:008/1/1957 12:008/1...
# ...

# %%
ufo_state

# %%
ufo_state = ufo.groupby("State").count()

# %%
ufo_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
ufo_state.sort_values(by = "Time",
                     ascending = False,
                     inplace = True)

# %%
ufo_state[:10].Time.plot(kind = "bar")

# %%
ufo.groupby(["State", "City"]).count()
# Out:
#                                                           Colors Reported  \
# State City
# AK    Adak                                                              0
#       Alaska                                                            0
#       Anchorage                                                         2
#       Arctic                                                            0
#       Auke Bay                                                          2
#       Bering Sea                                                        1
#       Bethel                                                            0
#       Big Lake                                                          1
#       Cantwell                                                          0
#       Chugiak                                                           0
#       Cold Bay                                                          0
# ...

# %%
ufo.groupby(["State", "City"]).count().reset_index()
# Out:
#      State                                               City  \
# 0       AK                                               Adak
# 1       AK                                             Alaska
# 2       AK                                          Anchorage
# 3       AK                                             Arctic
# 4       AK                                           Auke Bay
# 5       AK                                         Bering Sea
# 6       AK                                             Bethel
# 7       AK                                           Big Lake
# 8       AK                                           Cantwell
# 9       AK                                            Chugiak
# 10      AK                                           Cold Bay
# 11      AK                                      Copper Center
# 12      AK                                            Cordova
# 13      AK                                     Delta Junction
# ...

# %% [markdown]
# ### datetime

# %%
ufo["datetime"] = pd.to_datetime(ufo.Time)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#              datetime  month  weekday
# 0 1930-06-01 22:00:00      6   Sunday
# 1 1930-06-30 20:00:00      6   Monday
# 2 1931-02-15 14:00:00      2   Sunday
# 3 1931-06-01 13:00:00      6   Monday
# 4 1933-04-18 19:00:00      4  Tuesday

# %%
import datetime as dt

# %%
ufo["month"] = ufo.datetime.dt.month

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#              datetime  month  weekday
# 0 1930-06-01 22:00:00      6   Sunday
# 1 1930-06-30 20:00:00      6   Monday
# 2 1931-02-15 14:00:00      2   Sunday
# 3 1931-06-01 13:00:00      6   Monday
# 4 1933-04-18 19:00:00      4  Tuesday

# %%
ufo["weekday"] = ufo.datetime.dt.weekday_name

# %%
ufo.head
# Out:
# <bound method NDFrame.head of                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo_weekdays = ufo.groupby("weekday").count()

# %%
ufo_weekdays.sort_values(by = "Time",
                        ascending = False,
                        inplace = True)

# %%
ufo_weekdays.Time.plot(kind = "bar")
